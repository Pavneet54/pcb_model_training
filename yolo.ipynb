# %%
import torch

print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
else:
    print("No GPU detected")
# Out:
# CUDA available: True
# GPU: Tesla T4

# %%
# ══════════════════════════════════════════════════════════════
# CELL 1 — Install
# ══════════════════════════════════════════════════════════════
# !pip install -q ultralytics
import torch
from ultralytics import YOLO
from pathlib import Path
import yaml, os, shutil

print(f"✅ PyTorch  : {torch.__version__}")
print(f"✅ CUDA     : {torch.cuda.is_available()}")
print(f"✅ GPU      : {torch.cuda.get_device_name(0)}")
print(f"✅ VRAM     : {torch.cuda.get_device_properties(0).total_memory/1e9:.1f} GB")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 42.8 MB/s eta 0:00:00
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ✅ PyTorch  : 2.10.0+cu128
# ✅ CUDA     : True
# ✅ GPU      : Tesla T4
# ✅ VRAM     : 15.6 GB

# %%
# ══════════════════════════════════════════════════════════════
# CELL 2 — Paths
# ══════════════════════════════════════════════════════════════
from pathlib import Path

DATASET  = Path("/Users/pavneet/Desktop/industry45/PCBSegClassNet/data/yolo")
RUNS_DIR = Path("/Users/pavneet/Desktop/industry45/runs_best_models")
RUNS_DIR.mkdir(parents=True, exist_ok=True)

print("=" * 50)
print("  DATASET CHECK")
print("=" * 50)
print(f"  Path         : {DATASET}")
print(f"  Exists       : {DATASET.exists()}")
print(f"  Train images : {len(list((DATASET/'train/images').glob('*.png')))}")
print(f"  Train labels : {len(list((DATASET/'train/labels').glob('*.txt')))}")
print(f"  Val images   : {len(list((DATASET/'val/images').glob('*.png')))}")
print(f"  Val labels   : {len(list((DATASET/'val/labels').glob('*.txt')))}")
print(f"  Runs dir     : {RUNS_DIR}")
print("=" * 50)
# Out:
# ...
#   DATASET CHECK
# ...
#   Path         : /Users/pavneet/Desktop/industry45/PCBSegClassNet/data/yolo
#   Exists       : False
#   Train images : 0
#   Train labels : 0
#   Val images   : 0
#   Val labels   : 0
#   Runs dir     : /Users/pavneet/Desktop/industry45/runs_best_models
# ...
